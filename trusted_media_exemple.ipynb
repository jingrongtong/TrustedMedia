# %%
from image_generator import ImageGenerator

# %% [markdown]
# # Media libre

# %% [markdown]
# ## Madrid : Des manifestations sans précédent suite à l'élection de Juan Escobar.
# 25/02/2021
# Dans la journée de mardi, des centaines de voitures mises à feu sous le jugement des protestataires qui sillonnent les rues de Madrid. Les autoritées décrivent la situation comme critique et appelle au calme suite à de nombreuses dégradations de biens publics.
#
# ##### Crédit : Esteban Sanchez; 23/02/2021; Madrid

# %%
image_generator = ImageGenerator("test2_exif.jpg")
image_generator.load_image_file()
image_generator.display()
# Out:
# 7B Blvd de Rochechouart, 75009 Paris
# DateTime b'2020:01:23 14:32:45'.
# GPSAltitude (3524, 100), GPSLatitude (4888, 100), GPSLongitude (234, 100)
